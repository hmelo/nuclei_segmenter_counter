# %% [markdown]
# # Assignment 2
#
# ### Hans Melo, PhD. AI Vali
# #### hans.melo@mail.utoronto.ca
# #### Due: April 9 2018
#
# #### Summary
#
# The purpose of this project is to demonstrate a simple application of deep learning for solving a problem within digital pathology, our startup's domain. Some of the main image analysis tasks in digital pathology include detection and counting (e.g., mitotic events), segmentation (e.g., nuclei), and tissue classification (e.g., cancerous vs. non-cancerous). Unfortunately, issues with slide preparation, variations in staining and scanning across sites, and vendor platforms, as well as biological variance, such as the presentation of different grades of disease, make these image analysis tasks particularly challenging [1]. Traditional approaches rely heavily on task-specific “handcrafted” features and require extensive manual tuning to accommodate these variances which is expensive and inefficient [1,2]. Deep learning may be ideally suited to tackle these challenges as it offers a more domain agnostic approach combining both feature discovery and implementation to maximally discriminate between the classes of interest.
#
# The first step towards tackling these issues is perhaps to create a general AI tool to help pathlogoists segment and count cells within a sample slide.
#
# In this notebook, I demonstrate such a cell segmentation tool by training a deep convolutional neural network on cell images acquired from the  [2018 Science Bowl Kaggle competition](https://www.kaggle.com/c/data-science-bowl-2018) (data available after registration). Specifically, training was performed on 670 labeled images using a U-Net architecture [1], with a 90/10 train/validation split, testing was done on an additional 65 images. This dataset is particularly useful as it includes different kinds of images with varying sizes, colours, modalities. Thus, the network learns to segment cells across different conditions without handcraftining features. The network was implemented using Keras and Tensorflow. Additionally, I created a simple function to count the number of cells after segmentation.
#
# Overall the model does a good job at segmenting images and counting cells. Future development will focus on classification and counting of different cell types.
#
# This notebook includes the following sections:
# <ol>
# <li> Import required libraries</li>
# <li>Load datasets</li>
# <li>Image preprocessing</li>
# <li>Data Visualization</li>
# <li>Setup U-net model</li>
# <li>Training</li>
# <li>Prediction</li>
# <li>Visualize Results</li>
# <li>Cell Counting</li>
# </ol>
#
# [1] Janowczyk, A., & Madabhushi, A. (2016). Deep learning for digital pathology image analysis: A comprehensive tutorial with selected use cases. Journal of pathology informatics, 7.
#
# [2] Litjens, G., Kooi, T., Bejnordi, B. E., Setio, A. A. A., Ciompi, F., Ghafoorian, M., ... & Sánchez, C. I. (2017). A survey on deep learning in medical image analysis. Medical image analysis, 42, 60-88.

# %% [markdown]
# ## 1) Import required libraries

# %%
# %matplotlib inline
import os
import random
import sys
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from PIL import Image
import cv2
import h5py
from help_functions import *
#from skimage.color import rgb2gray

import tensorflow as tf

from keras.utils import Progbar
from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose,Convolution2D
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')

# Setting seed for reproducibility
seed = 41
random.seed = seed
np.random.seed = seed
smooth = 1.
epochs = 50

# %% [markdown]
# ## 2) Load datasets
#
# Here we'll try two file formats hdf5 and numpy arrays.
#
# ### First lets try hfd5:

# %%
# Data Path
TRAIN_PATH = '../Nuclei/stage1_train/'
TEST_PATH = '../Nuclei/stage1_test/'
dataset_path = 'datasets_hdf5/'

# %%
# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]
print(len(test_ids))
# Out:
# 65

# %%
# Get data in hdf5 format if available or convert original images to hdf5 format.

Nimgs=len(train_ids)
N_test_imgs=len(test_ids)
IMG_WIDTH=256
IMG_HEIGHT=256
IMG_CHANNELS=3

def write_hdf5(arr,outfile):
  with h5py.File(outfile,"w") as f:
    f.create_dataset("image", data=arr, dtype=arr.dtype)
    
def load_hdf5(infile):
  with h5py.File(infile,"r") as f:  #"with" close the file after its nested commands
    return f["image"][()]
    
def get_train_dataset(train_img_hdf5_file, train_mask_hdf5_file):
    imgs = np.zeros((Nimgs,IMG_HEIGHT,IMG_WIDTH,IMG_CHANNELS))
    groundTruth = np.zeros((Nimgs,IMG_HEIGHT,IMG_WIDTH,1))
    # load from hdf5 if it exists
    if os.path.isfile(dataset_path+train_img_hdf5_file) and os.path.isfile(dataset_path+train_mask_hdf5_file):
        print("Train dataset found and loaded from memory.")
        imgs = load_hdf5(dataset_path+train_img_hdf5_file)
        groundTruth = load_hdf5(dataset_path+train_mask_hdf5_file)
        return imgs, groundTruth
    a = Progbar(len(train_ids))
    # if hdf5 doesn't exist then load original images and create hdf5
    print("hdf5 files not found, creating hdf5 from original dataset...")
    for n, id_ in enumerate(train_ids):
        path = TRAIN_PATH + id_
        img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
        img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
        imgs[n] = np.asarray(img)
        #print('img.shape=',img.shape)
        #print('imgs.shape=',imgs.shape)
        
        # create merged mask     
        mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
        for mask_file in next(os.walk(path + '/masks/'))[2]:
            mask_ = imread(path + '/masks/' + mask_file)
            mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant', 
                                        preserve_range=True), axis=-1)
            mask = np.maximum(mask, mask_)
        groundTruth[n] = np.asarray(mask)
        a.update(n)
        ###

    print "imgs max: " +str(np.max(imgs))
    print "imgs min: " +str(np.min(imgs))
    assert(np.max(groundTruth)==255)
    assert(np.min(groundTruth)==0)
    print "Masks are correctly within pixel value range 0-255 (black-white)"
    #reshaping for my standard tensors
    imgs = np.transpose(imgs,(0,3,1,2))
    assert(imgs.shape == (Nimgs,IMG_CHANNELS,IMG_HEIGHT,IMG_WIDTH))
    groundTruth = np.reshape(groundTruth,(Nimgs,1,IMG_HEIGHT,IMG_WIDTH))
    assert(groundTruth.shape == (Nimgs,1,IMG_HEIGHT,IMG_WIDTH))
    write_hdf5(imgs, dataset_path + train_img_hdf5_file)
    write_hdf5(groundTruth, dataset_path + train_mask_hdf5_file)
    return imgs, groundTruth

def get_test_dataset(test_img_hdf5_file):
    imgs = np.zeros((N_test_imgs,IMG_HEIGHT,IMG_WIDTH,IMG_CHANNELS))
    # load from hdf5 if it exists
    if os.path.isfile(dataset_path+test_img_hdf5_file):
        print("Test dataset found and loaded from memory.")
        imgs = load_hdf5(dataset_path+test_img_hdf5_file)
        return imgs
    a = Progbar(len(test_ids))
    # if hdf5 doesn't exist then load original images and create hdf5
    print("hdf5 test files not found, creating hdf5 from original dataset...")
    for n, id_ in enumerate(test_ids):
        path = TEST_PATH + id_
        img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
        img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
        imgs[n] = np.asarray(img)
        a.update(n)
        ###
    print "imgs max: " +str(np.max(imgs))
    print "imgs min: " +str(np.min(imgs))
    #reshaping for my standard tensors
    imgs = np.transpose(imgs,(0,3,1,2))
    assert(imgs.shape == (N_test_imgs,IMG_CHANNELS,IMG_HEIGHT,IMG_WIDTH))
    write_hdf5(imgs, dataset_path + test_img_hdf5_file)
    return imgs

# %%
# Get hdf5 datasets
train_img_hdf5_file="Nuclei_dataset_imgs_train.hdf5"
train_mask_hdf5_file="Nuclei_dataset_masks_train.hdf5"
test_img_hdf5_file="Nuclei_dataset_imgs_test.hdf5"
hdf5_imgs_train, hdf5_train_masks = get_train_dataset(train_img_hdf5_file, train_mask_hdf5_file)
hdf5_imgs_test = get_test_dataset(test_img_hdf5_file)
# Out:
# Train dataset found and loaded from memory.
# Test dataset found and loaded from memory.

# %%
print(hdf5_imgs_train.shape)
print(hdf5_imgs_test.shape)
print(hdf5_train_masks.shape)
# Out:
# (670, 3, 256, 256)
# (65, 3, 256, 256)
# (670, 1, 256, 256)

# %% [markdown]
# ### Now let's try the numpy array format:

# %%
# Read train images and masks return as numpy array
def read_train_data(IMG_WIDTH=256,IMG_HEIGHT=256,IMG_CHANNELS=3):
    X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
    Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    print('Getting and resizing train images and masks ... ')
    sys.stdout.flush()
    if os.path.isfile("train_img.npy") and os.path.isfile("train_mask.npy"):
        print("Train file loaded from memory")
        X_train = np.load("train_img.npy")
        Y_train = np.load("train_mask.npy")
        return X_train,Y_train
    a = Progbar(len(train_ids))
    for n, id_ in enumerate(train_ids):
        path = TRAIN_PATH + id_
        img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
        img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
        X_train[n] = img
        mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
        for mask_file in next(os.walk(path + '/masks/'))[2]:
            mask_ = imread(path + '/masks/' + mask_file)
            mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant', 
                                        preserve_range=True), axis=-1)
            mask = np.maximum(mask, mask_)
        Y_train[n] = mask
        a.update(n)
    np.save("train_img",X_train)
    np.save("train_mask",Y_train)
    return X_train,Y_train

# %%
# Read test images and return as numpy array
def read_test_data(IMG_WIDTH=256,IMG_HEIGHT=256,IMG_CHANNELS=3):
    X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
    sizes_test = []
    print('\nGetting and resizing test images ... ')
    sys.stdout.flush()
    if os.path.isfile("test_img.npy") and os.path.isfile("test_size.npy"):
        print("Test file loaded from memory")
        X_test = np.load("test_img.npy")
        sizes_test = np.load("test_size.npy")
        return X_test,sizes_test
    b = Progbar(len(test_ids))
    for n, id_ in enumerate(test_ids):
        path = TEST_PATH + id_
        img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
        sizes_test.append([img.shape[0], img.shape[1]])
        img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
        X_test[n] = img
        b.update(n)
    np.save("test_img",X_test)
    np.save("test_size",sizes_test)
    return X_test,sizes_test

# %%
## Read data from numpy array
# get train_data
train_imgs,train_masks = read_train_data()

# get test_data
test_imgs,test_img_sizes = read_test_data()
# Out:
# Getting and resizing train images and masks ...
# Train file loaded from memory
#
# Getting and resizing test images ...
# Test file loaded from memory

# %% [markdown]
# ## 3) Image preprocessing

# %%
# Image Preprocessing

def my_PreProc(data):
    assert(len(data.shape)==4)
    assert (data.shape[1]==3)  #Use the original images
    #black-white conversion
    #imgs = rgb2gray(data)
    #my preprocessing:
    imgs = dataset_normalized(data)
    #imgs = clahe_equalized(imgs)
    imgs = adjust_gamma(imgs, 1.2)
    imgs = imgs/255.  #reduce to 0-1 range
    return imgs


#============================================================
#========= PRE PROCESSING FUNCTIONS ========================#
#============================================================

#==== histogram equalization
def histo_equalized(imgs):
    #assert (len(imgs.shape)==4)  #4D arrays
    #assert (imgs.shape[1]==1)  #check the channel is 1
    imgs_equalized = np.empty(imgs.shape)
    for i in range(imgs.shape[0]):
        imgs_equalized[i,0] = cv2.equalizeHist(np.array(imgs[i,0], dtype = np.uint8))
    return imgs_equalized


# CLAHE (Contrast Limited Adaptive Histogram Equalization)
#adaptive histogram equalization is used. In this, image is divided into small blocks called "tiles" (tileSize is 8x8 by default in OpenCV). Then each of these blocks are histogram equalized as usual. So in a small area, histogram would confine to a small region (unless there is noise). If noise is there, it will be amplified. To avoid this, contrast limiting is applied. If any histogram bin is above the specified contrast limit (by default 40 in OpenCV), those pixels are clipped and distributed uniformly to other bins before applying histogram equalization. After equalization, to remove artifacts in tile borders, bilinear interpolation is applied
def clahe_equalized(imgs):
    #assert (len(imgs.shape)==4)  #4D arrays
    #assert (imgs.shape[1]==1)  #check the channel is 1
    #create a CLAHE object (Arguments are optional).
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    imgs_equalized = np.empty(imgs.shape)
    for i in range(imgs.shape[0]):
        imgs_equalized[i,0] = clahe.apply(np.array(imgs[i,0], dtype = np.uint8))
    return imgs_equalized


# ===== normalize over the dataset
def dataset_normalized(imgs):
    #assert (len(imgs.shape)==4)  #4D arrays
    #assert (imgs.shape[1]==1)  #check the channel is 1
    imgs_normalized = np.empty(imgs.shape)
    imgs_std = np.std(imgs)
    imgs_mean = np.mean(imgs)
    imgs_normalized = (imgs-imgs_mean)/imgs_std
    for i in range(imgs.shape[0]):
        imgs_normalized[i] = ((imgs_normalized[i] - np.min(imgs_normalized[i])) / (np.max(imgs_normalized[i])-np.min(imgs_normalized[i])))*255
    return imgs_normalized


def adjust_gamma(imgs, gamma=1.0):
    #assert (len(imgs.shape)==4)  #4D arrays
    #assert (imgs.shape[1]==1)  #check the channel is 1
    # build a lookup table mapping the pixel values [0, 255] to
    # their adjusted gamma values
    invGamma = 1.0 / gamma
    table = np.array([((i / 255.0) ** invGamma) * 255 for i in np.arange(0, 256)]).astype("uint8")
    # apply gamma correction using the lookup table
    new_imgs = np.empty(imgs.shape)
    for i in range(imgs.shape[0]):
        new_imgs[i,0] = cv2.LUT(np.array(imgs[i,0], dtype = np.uint8), table)
    return new_imgs

# %% [markdown]
# #### Apply preprocessing to both hdf5 and numpy format images

# %%
# Apply preprocessing to original images:
trans_train_imgs=np.transpose(train_imgs,(0,3,1,2)) # need to transpose it to get the right dims
preproc_imgs = my_PreProc(trans_train_imgs)
preproc_imgs=np.transpose(preproc_imgs,(0,2,3,1)) # need to transpose again it to get the right dims

trans_test_imgs=np.transpose(test_imgs,(0,3,1,2)) # need to transpose it to get the right dims
preproc_test_imgs = my_PreProc(trans_test_imgs)
preproc_test_imgs=np.transpose(preproc_test_imgs,(0,2,3,1)) # need to transpose again it to get the right dims

# apply preprocessing to hdf5 images
hdf5_preproc_imgs = my_PreProc(hdf5_imgs_train)
hdf5_preproc_imgs=np.transpose(hdf5_preproc_imgs,(0,2,3,1))
hdf5_masks=np.transpose(hdf5_train_masks,(0,2,3,1))

# %% [markdown]
# ## 4) Data Visualization
#
# Let's check that the data looks ok before we move on to the model.

# %%
# Check if training data looks alright
ix = random.randint(0, len(train_ids))
print("Showing training image no:",ix)
mask_img = np.squeeze(train_masks[ix])
preproc_img = preproc_imgs[ix]

# Plot samples images
fig = plt.figure(figsize=(12, 12))
plt.subplot(131).set_title('Original')
plt.imshow(train_imgs[ix])
plt.subplot(132).set_title('Mask (Target)')
plt.imshow(mask_img)
plt.subplot(133).set_title('Preprocessed')
plt.imshow(preproc_img)
plt.show()

# Check hdf5 data

hdf5_img = np.transpose(hdf5_imgs_train,(0,2,3,1))[ix]
hdf5_floor_img = np.floor(hdf5_img)
hdf5_mask=np.squeeze(hdf5_masks[ix])
hdf5_preproc_img=hdf5_preproc_imgs[ix]


# Plot hdf5 samples images
fig = plt.figure(figsize=(12, 12))
plt.subplot(141).set_title('HDF5 Image')
plt.imshow(hdf5_img)
plt.subplot(142).set_title('HDF5 Floor')
plt.imshow(hdf5_floor_img)
plt.subplot(143).set_title('HDF5 Mask')
plt.imshow(hdf5_mask)
plt.subplot(144).set_title('HDF5 Preprocessed')
plt.imshow(hdf5_preproc_img)
plt.show()

# Check a random test image
x = random.randint(0, len(test_ids))
print('Show Random test image:',x)
plt.imshow(test_imgs[x]) 
plt.show()
print('Show Random test image:',x)
plt.imshow(preproc_test_imgs[x]) 
plt.show()
# Out:
# ('Showing training image no:', 562)
# ('Show Random test image:', 14)
# ('Show Random test image:', 14)

# %% [markdown]
# The data looks ok. Note the in hdf5 format resizing introduces noise which seems to be corrected later in the preprocessing steps.

# %% [markdown]
# ## 5) Setup U-net model
#
# First we'll setup potential metric functions to judge the performance of the model.

# %%
# Metric function
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# Loss funtion
def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %%
# Define IoU metric
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2, y_true)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %%
def iou_coef(y_true, y_pred, smooth=1):
    
    """
    IoU = (|X & Y|)/ (|X or Y|)
    """
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f,-1) + K.sum(y_pred_f,-1) - intersection
    return (intersection + smooth) / ( union + smooth)

def iou_coef_loss(y_true, y_pred):
    return -iou_coef(y_true, y_pred)

# %% [markdown]
# ### Here is the U-Net model implemented in Keras

# %% [markdown]
# U-net is a popular convolutional network architecture for fast and precise segmentation of images. It has received much praise for winning a number of competitions including the Grand Challenge for Computer-Automated Detection of Caries in Bitewing Radiography at ISBI 2015, and the Cell Tracking Challenge at ISBI 2015 on the two most challenging transmitted light microscopy categories (Phase contrast and DIC microscopy) by a large margin (See also our annoucement).
#
# The architecture consists of a contracting path to capture context and a symmetric expanding path that enables precise localization. One important advantage of this architecture is that it it has shown very good performance with small sample sizes, as is the case with the data I use here.
#
# ![title](u-net-architecture.png)
#
#
# Ronneberger, O., Fischer, P., & Brox, T. (2015, October). U-net: Convolutional networks for biomedical image segmentation. In International Conference on Medical image computing and computer-assisted intervention (pp. 234-241). Springer, Cham.

# %%
def get_unet(IMG_WIDTH=256,IMG_HEIGHT=256,IMG_CHANNELS=3):
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    s = Lambda(lambda x: x / 255) (inputs)
    c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s)
    c1 = Dropout(0.1) (c1)
    c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
    p1 = MaxPooling2D((2, 2)) (c1)
    c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
    c2 = Dropout(0.1) (c2)
    c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
    p2 = MaxPooling2D((2, 2)) (c2)

    c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
    c3 = Dropout(0.2) (c3)
    c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
    p3 = MaxPooling2D((2, 2)) (c3)

    c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
    c4 = Dropout(0.2) (c4)
    c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
    p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

    c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
    c5 = Dropout(0.3) (c5)
    c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
    c6 = Dropout(0.2) (c6)
    c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
    c7 = Dropout(0.2) (c7)
    c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
    c8 = Dropout(0.1) (c8)
    c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
    c9 = Dropout(0.1) (c9)
    c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

    outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

    model = Model(inputs=[inputs], outputs=[outputs])
    model.compile(optimizer='adam',loss='binary_crossentropy', metrics=[iou_coef])
    return model

# %% [markdown]
# # 6) Training
# ### Now we're ready to train the model
#
# We'll set early stopping with a patience of 10 in case we decide to use it later. So, if the validation loss doesn't improve after 10 epochs then the model stops. We also set checkpointer which saves the model weights everytime it sees an improvement. I picked a batch_size of 16 based on what my gpu memory allowed.
#
# In the end, I decided to run it for 100 epochs without early stopping.
#
# I ran this on a Titan X GPU with 12GB of memory, it takes about 5 minutes to run 50 epochs.
#
# ### WARNING: Training this model on a CPU is not recommended as it will take several hours or even days to complete. Instead, skip to section 7 and try loading the pre-trained weights privided.

# %%
# get u_net model
model = get_unet()

# %% [markdown]
# ### Try 2 runs
#
# 1. Train the a model on the numpy data without preproccessing.
# 2. Train the a model on the numpy data numpy data with prerpoccessing.

# %%
# 1. Train model on numpy train_data without preprocessing
print("\nTraining model...")

earlystopper = EarlyStopping(patience=10, verbose=1)
checkpointer = ModelCheckpoint('model-1-dsbowl2018_iou_coef_e100b16.h5', verbose=1, save_best_only=True)
results = u_net.fit(train_imgs,train_masks, validation_split=0.1, batch_size=16, epochs=100, 
                    callbacks=[checkpointer])
# Out:
# Training model...
# Train on 603 samples, validate on 67 samples
# Epoch 1/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.4057 - iou_coef: 0.1349
# Epoch 00001: val_loss improved from inf to 0.20089, saving model to model-1-dsbowl2018_iou_coef_e100b16.h5
# 603/603 [==============================] - 16s 27ms/step - loss: 0.4030 - iou_coef: 0.1378 - val_loss: 0.2009 - val_iou_coef: 0.3883
# Epoch 2/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.1691 - iou_coef: 0.5140
# Epoch 00002: val_loss improved from 0.20089 to 0.13603, saving model to model-1-dsbowl2018_iou_coef_e100b16.h5
# 603/603 [==============================] - 10s 16ms/step - loss: 0.1676 - iou_coef: 0.5166 - val_loss: 0.1360 - val_iou_coef: 0.6172
# Epoch 3/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.1260 - iou_coef: 0.6260
# Epoch 00003: val_loss improved from 0.13603 to 0.10851, saving model to model-1-dsbowl2018_iou_coef_e100b16.h5
# 603/603 [==============================] - 10s 16ms/step - loss: 0.1260 - iou_coef: 0.6257 - val_loss: 0.1085 - val_iou_coef: 0.6607
# Epoch 4/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.1045 - iou_coef: 0.6706
# Epoch 00004: val_loss improved from 0.10851 to 0.10393, saving model to model-1-dsbowl2018_iou_coef_e100b16.h5
# 603/603 [==============================] - 10s 16ms/step - loss: 0.1051 - iou_coef: 0.6699 - val_loss: 0.1039 - val_iou_coef: 0.6929
# Epoch 5/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0973 - iou_coef: 0.6945
# Epoch 00005: val_loss did not improve
# 603/603 [==============================] - 9s 16ms/step - loss: 0.0967 - iou_coef: 0.6960 - val_loss: 0.1044 - val_iou_coef: 0.7017
# Epoch 6/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0925 - iou_coef: 0.7031
# Epoch 00006: val_loss improved from 0.10393 to 0.09098, saving model to model-1-dsbowl2018_iou_coef_e100b16.h5
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0923 - iou_coef: 0.7041 - val_loss: 0.0910 - val_iou_coef: 0.7238
# Epoch 7/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0847 - iou_coef: 0.7269
# Epoch 00007: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0847 - iou_coef: 0.7264 - val_loss: 0.0947 - val_iou_coef: 0.7193
# Epoch 8/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0837 - iou_coef: 0.7316
# Epoch 00008: val_loss improved from 0.09098 to 0.08185, saving model to model-1-dsbowl2018_iou_coef_e100b16.h5
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0836 - iou_coef: 0.7328 - val_loss: 0.0819 - val_iou_coef: 0.7330
# Epoch 9/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0790 - iou_coef: 0.7374
# Epoch 00009: val_loss improved from 0.08185 to 0.07832, saving model to model-1-dsbowl2018_iou_coef_e100b16.h5
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0787 - iou_coef: 0.7381 - val_loss: 0.0783 - val_iou_coef: 0.7364
# Epoch 10/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0769 - iou_coef: 0.7442
# Epoch 00010: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0771 - iou_coef: 0.7443 - val_loss: 0.0891 - val_iou_coef: 0.7260
# Epoch 11/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0817 - iou_coef: 0.7330
# Epoch 00011: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0821 - iou_coef: 0.7325 - val_loss: 0.0822 - val_iou_coef: 0.7359
# Epoch 12/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0788 - iou_coef: 0.7385
# Epoch 00012: val_loss did not improve
# 603/603 [==============================] - 10s 17ms/step - loss: 0.0784 - iou_coef: 0.7402 - val_loss: 0.0900 - val_iou_coef: 0.7239
# Epoch 13/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0784 - iou_coef: 0.7445
# Epoch 00013: val_loss improved from 0.07832 to 0.07470, saving model to model-1-dsbowl2018_iou_coef_e100b16.h5
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0780 - iou_coef: 0.7433 - val_loss: 0.0747 - val_iou_coef: 0.7476
# Epoch 14/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0756 - iou_coef: 0.7502
# Epoch 00014: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0754 - iou_coef: 0.7504 - val_loss: 0.0765 - val_iou_coef: 0.7377
# Epoch 15/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0780 - iou_coef: 0.7447
# Epoch 00015: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0784 - iou_coef: 0.7439 - val_loss: 0.0991 - val_iou_coef: 0.7009
# Epoch 16/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0771 - iou_coef: 0.7463
# Epoch 00016: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0773 - iou_coef: 0.7459 - val_loss: 0.0762 - val_iou_coef: 0.7460
# Epoch 17/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0739 - iou_coef: 0.7515
# Epoch 00017: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0738 - iou_coef: 0.7526 - val_loss: 0.0863 - val_iou_coef: 0.7326
# Epoch 18/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0761 - iou_coef: 0.7504
# Epoch 00018: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0758 - iou_coef: 0.7510 - val_loss: 0.0835 - val_iou_coef: 0.7138
# Epoch 19/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0732 - iou_coef: 0.7541
# Epoch 00019: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0737 - iou_coef: 0.7545 - val_loss: 0.0799 - val_iou_coef: 0.7484
# Epoch 20/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0721 - iou_coef: 0.7573
# Epoch 00020: val_loss improved from 0.07470 to 0.07416, saving model to model-1-dsbowl2018_iou_coef_e100b16.h5
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0715 - iou_coef: 0.7589 - val_loss: 0.0742 - val_iou_coef: 0.7552
# Epoch 21/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0723 - iou_coef: 0.7573
# Epoch 00021: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0726 - iou_coef: 0.7573 - val_loss: 0.0764 - val_iou_coef: 0.7448
# Epoch 22/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0714 - iou_coef: 0.7599
# Epoch 00022: val_loss improved from 0.07416 to 0.07117, saving model to model-1-dsbowl2018_iou_coef_e100b16.h5
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0714 - iou_coef: 0.7604 - val_loss: 0.0712 - val_iou_coef: 0.7362
# Epoch 23/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0704 - iou_coef: 0.7607
# Epoch 00023: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0703 - iou_coef: 0.7598 - val_loss: 0.0862 - val_iou_coef: 0.7400
# Epoch 24/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0699 - iou_coef: 0.7688
# Epoch 00024: val_loss improved from 0.07117 to 0.06956, saving model to model-1-dsbowl2018_iou_coef_e100b16.h5
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0697 - iou_coef: 0.7677 - val_loss: 0.0696 - val_iou_coef: 0.7456
# Epoch 25/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0721 - iou_coef: 0.7591
# Epoch 00025: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0716 - iou_coef: 0.7599 - val_loss: 0.0715 - val_iou_coef: 0.7517
# Epoch 26/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0708 - iou_coef: 0.7612
# Epoch 00026: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0705 - iou_coef: 0.7621 - val_loss: 0.0729 - val_iou_coef: 0.7435
# Epoch 27/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0729 - iou_coef: 0.7592
# Epoch 00027: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0725 - iou_coef: 0.7599 - val_loss: 0.0731 - val_iou_coef: 0.7522
# Epoch 28/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0687 - iou_coef: 0.7663
# Epoch 00028: val_loss improved from 0.06956 to 0.06923, saving model to model-1-dsbowl2018_iou_coef_e100b16.h5
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0683 - iou_coef: 0.7667 - val_loss: 0.0692 - val_iou_coef: 0.7477
# Epoch 29/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0689 - iou_coef: 0.7662
# Epoch 00029: val_loss improved from 0.06923 to 0.06804, saving model to model-1-dsbowl2018_iou_coef_e100b16.h5
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0689 - iou_coef: 0.7667 - val_loss: 0.0680 - val_iou_coef: 0.7586
# Epoch 30/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0662 - iou_coef: 0.7755
# Epoch 00030: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0660 - iou_coef: 0.7758 - val_loss: 0.0686 - val_iou_coef: 0.7548
# Epoch 31/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0659 - iou_coef: 0.7730
# Epoch 00031: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0658 - iou_coef: 0.7736 - val_loss: 0.0706 - val_iou_coef: 0.7495
# Epoch 32/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0666 - iou_coef: 0.7726
# Epoch 00032: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0669 - iou_coef: 0.7726 - val_loss: 0.0703 - val_iou_coef: 0.7618
# Epoch 33/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0677 - iou_coef: 0.7696
# Epoch 00033: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0678 - iou_coef: 0.7696 - val_loss: 0.0722 - val_iou_coef: 0.7586
# Epoch 34/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0695 - iou_coef: 0.7710
# Epoch 00034: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0691 - iou_coef: 0.7706 - val_loss: 0.0711 - val_iou_coef: 0.7637
# Epoch 35/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0664 - iou_coef: 0.7727
# Epoch 00035: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0665 - iou_coef: 0.7731 - val_loss: 0.0721 - val_iou_coef: 0.7523
# Epoch 36/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0658 - iou_coef: 0.7754
# Epoch 00036: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0657 - iou_coef: 0.7759 - val_loss: 0.0703 - val_iou_coef: 0.7433
# Epoch 37/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0635 - iou_coef: 0.7817
# Epoch 00037: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0632 - iou_coef: 0.7821 - val_loss: 0.0710 - val_iou_coef: 0.7719
# Epoch 38/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0633 - iou_coef: 0.7838
# Epoch 00038: val_loss improved from 0.06804 to 0.06793, saving model to model-1-dsbowl2018_iou_coef_e100b16.h5
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0638 - iou_coef: 0.7832 - val_loss: 0.0679 - val_iou_coef: 0.7593
# Epoch 39/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0660 - iou_coef: 0.7748
# Epoch 00039: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0655 - iou_coef: 0.7764 - val_loss: 0.0756 - val_iou_coef: 0.7700
# Epoch 40/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0647 - iou_coef: 0.7793
# Epoch 00040: val_loss improved from 0.06793 to 0.06599, saving model to model-1-dsbowl2018_iou_coef_e100b16.h5
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0647 - iou_coef: 0.7791 - val_loss: 0.0660 - val_iou_coef: 0.7696
# Epoch 41/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0650 - iou_coef: 0.7788
# Epoch 00041: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0645 - iou_coef: 0.7785 - val_loss: 0.0766 - val_iou_coef: 0.7749
# Epoch 42/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0619 - iou_coef: 0.7866
# Epoch 00042: val_loss improved from 0.06599 to 0.06442, saving model to model-1-dsbowl2018_iou_coef_e100b16.h5
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0622 - iou_coef: 0.7858 - val_loss: 0.0644 - val_iou_coef: 0.7795
# Epoch 43/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0628 - iou_coef: 0.7858
# Epoch 00043: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0628 - iou_coef: 0.7861 - val_loss: 0.0646 - val_iou_coef: 0.7693
# Epoch 44/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0624 - iou_coef: 0.7858
# Epoch 00044: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0620 - iou_coef: 0.7866 - val_loss: 0.0708 - val_iou_coef: 0.7652
# Epoch 45/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0629 - iou_coef: 0.7829
# Epoch 00045: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0628 - iou_coef: 0.7833 - val_loss: 0.0659 - val_iou_coef: 0.7768
# Epoch 46/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0615 - iou_coef: 0.7893
# Epoch 00046: val_loss did not improve
# 603/603 [==============================] - 9s 16ms/step - loss: 0.0626 - iou_coef: 0.7885 - val_loss: 0.0746 - val_iou_coef: 0.7642
# Epoch 47/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0622 - iou_coef: 0.7862
# Epoch 00047: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0624 - iou_coef: 0.7856 - val_loss: 0.0686 - val_iou_coef: 0.7695
# Epoch 48/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0598 - iou_coef: 0.7955
# Epoch 00048: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0598 - iou_coef: 0.7942 - val_loss: 0.0666 - val_iou_coef: 0.7662
# Epoch 49/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0595 - iou_coef: 0.7943
# Epoch 00049: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0595 - iou_coef: 0.7931 - val_loss: 0.0777 - val_iou_coef: 0.7546
# Epoch 50/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0629 - iou_coef: 0.7809
# Epoch 00050: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0625 - iou_coef: 0.7819 - val_loss: 0.0747 - val_iou_coef: 0.7635
# Epoch 51/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0588 - iou_coef: 0.7963
# Epoch 00051: val_loss improved from 0.06442 to 0.06237, saving model to model-1-dsbowl2018_iou_coef_e100b16.h5
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0589 - iou_coef: 0.7960 - val_loss: 0.0624 - val_iou_coef: 0.7794
# Epoch 52/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0581 - iou_coef: 0.7961
# Epoch 00052: val_loss did not improve
# 603/603 [==============================] - 9s 16ms/step - loss: 0.0576 - iou_coef: 0.7967 - val_loss: 0.0700 - val_iou_coef: 0.7841
# Epoch 53/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0573 - iou_coef: 0.7993
# Epoch 00053: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0576 - iou_coef: 0.7988 - val_loss: 0.0647 - val_iou_coef: 0.7600
# Epoch 54/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0569 - iou_coef: 0.8014
# Epoch 00054: val_loss did not improve
# 603/603 [==============================] - 9s 16ms/step - loss: 0.0567 - iou_coef: 0.8014 - val_loss: 0.0685 - val_iou_coef: 0.7567
# Epoch 55/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0556 - iou_coef: 0.8060
# Epoch 00055: val_loss did not improve
# 603/603 [==============================] - 9s 16ms/step - loss: 0.0554 - iou_coef: 0.8050 - val_loss: 0.0667 - val_iou_coef: 0.7680
# Epoch 56/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0560 - iou_coef: 0.8012
# Epoch 00056: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0560 - iou_coef: 0.8016 - val_loss: 0.0674 - val_iou_coef: 0.7864
# Epoch 57/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0552 - iou_coef: 0.8041
# Epoch 00057: val_loss did not improve
# 603/603 [==============================] - 9s 16ms/step - loss: 0.0553 - iou_coef: 0.8048 - val_loss: 0.0656 - val_iou_coef: 0.7651
# Epoch 58/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0553 - iou_coef: 0.8072
# Epoch 00058: val_loss did not improve
# 603/603 [==============================] - 9s 16ms/step - loss: 0.0549 - iou_coef: 0.8075 - val_loss: 0.0746 - val_iou_coef: 0.7799
# Epoch 59/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0548 - iou_coef: 0.8069
# Epoch 00059: val_loss did not improve
# 603/603 [==============================] - 10s 16ms/step - loss: 0.0546 - iou_coef: 0.8076 - val_loss: 0.0673 - val_iou_coef: 0.7685
# Epoch 60/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0541 - iou_coef: 0.8098
# Epoch 00060: val_loss did not improve
# 603/603 [==============================] - 9s 16ms/step - loss: 0.0535 - iou_coef: 0.8108 - val_loss: 0.0706 - val_iou_coef: 0.7764
# Epoch 61/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0514 - iou_coef: 0.8146
# Epoch 00061: val_loss did not improve
# 603/603 [==============================] - 9s 16ms/step - loss: 0.0516 - iou_coef: 0.8148 - val_loss: 0.0663 - val_iou_coef: 0.7820
# Epoch 62/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0530 - iou_coef: 0.8149
# Epoch 00062: val_loss did not improve
# 603/603 [==============================] - 9s 16ms/step - loss: 0.0529 - iou_coef: 0.8146 - val_loss: 0.0727 - val_iou_coef: 0.7638
# Epoch 63/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0546 - iou_coef: 0.8098
# Epoch 00063: val_loss did not improve
# 603/603 [==============================] - 9s 16ms/step - loss: 0.0541 - iou_coef: 0.8106 - val_loss: 0.0742 - val_iou_coef: 0.7622
# Epoch 64/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0518 - iou_coef: 0.8147
# Epoch 00064: val_loss did not improve
# 603/603 [==============================] - 9s 16ms/step - loss: 0.0518 - iou_coef: 0.8146 - val_loss: 0.0727 - val_iou_coef: 0.7811
# Epoch 65/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0494 - iou_coef: 0.8234
# Epoch 00065: val_loss did not improve
# 603/603 [==============================] - 9s 16ms/step - loss: 0.0493 - iou_coef: 0.8236 - val_loss: 0.0684 - val_iou_coef: 0.7866
# Epoch 66/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0497 - iou_coef: 0.8233
# Epoch 00066: val_loss did not improve
# 603/603 [==============================] - 9s 16ms/step - loss: 0.0495 - iou_coef: 0.8238 - val_loss: 0.0759 - val_iou_coef: 0.7792
# Epoch 67/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0481 - iou_coef: 0.8291
# Epoch 00067: val_loss did not improve
# 603/603 [==============================] - 9s 16ms/step - loss: 0.0481 - iou_coef: 0.8285 - val_loss: 0.0706 - val_iou_coef: 0.7798
# Epoch 68/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0474 - iou_coef: 0.8278
# Epoch 00068: val_loss did not improve
# 603/603 [==============================] - 9s 16ms/step - loss: 0.0471 - iou_coef: 0.8287 - val_loss: 0.0720 - val_iou_coef: 0.7829
# Epoch 69/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0466 - iou_coef: 0.8320
# Epoch 00069: val_loss did not improve
# 603/603 [==============================] - 9s 16ms/step - loss: 0.0463 - iou_coef: 0.8332 - val_loss: 0.0732 - val_iou_coef: 0.7884
# Epoch 70/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0458 - iou_coef: 0.8353
# Epoch 00070: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0457 - iou_coef: 0.8352 - val_loss: 0.0792 - val_iou_coef: 0.7846
# Epoch 71/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0447 - iou_coef: 0.8392
# Epoch 00071: val_loss did not improve
# 603/603 [==============================] - 9s 16ms/step - loss: 0.0447 - iou_coef: 0.8387 - val_loss: 0.0796 - val_iou_coef: 0.7816
# Epoch 72/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0468 - iou_coef: 0.8313
# Epoch 00072: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0468 - iou_coef: 0.8313 - val_loss: 0.0712 - val_iou_coef: 0.7813
# Epoch 73/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0450 - iou_coef: 0.8364
# Epoch 00073: val_loss did not improve
# 603/603 [==============================] - 9s 16ms/step - loss: 0.0449 - iou_coef: 0.8366 - val_loss: 0.0785 - val_iou_coef: 0.7909
# Epoch 74/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0422 - iou_coef: 0.8457
# Epoch 00074: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0425 - iou_coef: 0.8446 - val_loss: 0.0773 - val_iou_coef: 0.7894
# Epoch 75/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0419 - iou_coef: 0.8482
# Epoch 00075: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0420 - iou_coef: 0.8474 - val_loss: 0.0727 - val_iou_coef: 0.7881
# Epoch 76/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0409 - iou_coef: 0.8497
# Epoch 00076: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0412 - iou_coef: 0.8493 - val_loss: 0.0783 - val_iou_coef: 0.7927
# Epoch 77/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0414 - iou_coef: 0.8496
# Epoch 00077: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0414 - iou_coef: 0.8495 - val_loss: 0.0727 - val_iou_coef: 0.7940
# Epoch 78/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0400 - iou_coef: 0.8533
# Epoch 00078: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0400 - iou_coef: 0.8535 - val_loss: 0.0793 - val_iou_coef: 0.7933
# Epoch 79/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0395 - iou_coef: 0.8549
# Epoch 00079: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0397 - iou_coef: 0.8545 - val_loss: 0.0770 - val_iou_coef: 0.7970
# Epoch 80/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0392 - iou_coef: 0.8563
# Epoch 00080: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0391 - iou_coef: 0.8558 - val_loss: 0.0758 - val_iou_coef: 0.7979
# Epoch 81/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0381 - iou_coef: 0.8571
# Epoch 00081: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0385 - iou_coef: 0.8573 - val_loss: 0.0822 - val_iou_coef: 0.7977
# Epoch 82/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0380 - iou_coef: 0.8606
# Epoch 00082: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0379 - iou_coef: 0.8598 - val_loss: 0.0811 - val_iou_coef: 0.7897
# Epoch 83/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0374 - iou_coef: 0.8609
# Epoch 00083: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0374 - iou_coef: 0.8610 - val_loss: 0.0851 - val_iou_coef: 0.7965
# Epoch 84/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0371 - iou_coef: 0.8636
# Epoch 00084: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0370 - iou_coef: 0.8631 - val_loss: 0.0814 - val_iou_coef: 0.7985
# Epoch 85/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0371 - iou_coef: 0.8616
# Epoch 00085: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0371 - iou_coef: 0.8621 - val_loss: 0.0788 - val_iou_coef: 0.8016
# Epoch 86/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0444 - iou_coef: 0.8410
# Epoch 00086: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0441 - iou_coef: 0.8400 - val_loss: 0.0760 - val_iou_coef: 0.7767
# Epoch 87/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0514 - iou_coef: 0.8190
# Epoch 00087: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0514 - iou_coef: 0.8187 - val_loss: 0.0748 - val_iou_coef: 0.7697
# Epoch 88/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0485 - iou_coef: 0.8270
# Epoch 00088: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0484 - iou_coef: 0.8276 - val_loss: 0.0715 - val_iou_coef: 0.7838
# Epoch 89/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0415 - iou_coef: 0.8482
# Epoch 00089: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0415 - iou_coef: 0.8489 - val_loss: 0.0791 - val_iou_coef: 0.7946
# Epoch 90/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0385 - iou_coef: 0.8573
# Epoch 00090: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0382 - iou_coef: 0.8575 - val_loss: 0.0851 - val_iou_coef: 0.7948
# Epoch 91/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0363 - iou_coef: 0.8643
# Epoch 00091: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0366 - iou_coef: 0.8644 - val_loss: 0.0818 - val_iou_coef: 0.7986
# Epoch 92/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0356 - iou_coef: 0.8657
# Epoch 00092: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0357 - iou_coef: 0.8664 - val_loss: 0.0813 - val_iou_coef: 0.7998
# Epoch 93/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0352 - iou_coef: 0.8679
# Epoch 00093: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0352 - iou_coef: 0.8684 - val_loss: 0.0917 - val_iou_coef: 0.7951
# Epoch 94/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0346 - iou_coef: 0.8701
# Epoch 00094: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0349 - iou_coef: 0.8701 - val_loss: 0.0836 - val_iou_coef: 0.7961
# Epoch 95/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0348 - iou_coef: 0.8703
# Epoch 00095: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0348 - iou_coef: 0.8698 - val_loss: 0.0934 - val_iou_coef: 0.7922
# Epoch 96/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0339 - iou_coef: 0.8728
# Epoch 00096: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0340 - iou_coef: 0.8730 - val_loss: 0.0874 - val_iou_coef: 0.8015
# Epoch 97/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0344 - iou_coef: 0.8724
# Epoch 00097: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0343 - iou_coef: 0.8722 - val_loss: 0.0875 - val_iou_coef: 0.7961
# Epoch 98/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0337 - iou_coef: 0.8742
# Epoch 00098: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0340 - iou_coef: 0.8737 - val_loss: 0.0971 - val_iou_coef: 0.7957
# Epoch 99/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0331 - iou_coef: 0.8747
# Epoch 00099: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0332 - iou_coef: 0.8746 - val_loss: 0.0884 - val_iou_coef: 0.7997
# Epoch 100/100
# 592/603 [============================>.] - ETA: 0s - loss: 0.0344 - iou_coef: 0.8726
# Epoch 00100: val_loss did not improve
# 603/603 [==============================] - 9s 15ms/step - loss: 0.0341 - iou_coef: 0.8728 - val_loss: 0.0811 - val_iou_coef: 0.8062

# %% [markdown]
# As expected, the training and validation loss decrease repidly at first but then slows down and the validation interection over union coefficient (val_iou_coef) settles around .80, which is not bad.

# %%
# 2. Train model on numpy train_data with preprocessing
print("\nTraining...")

train_imgs,train_masks

earlystopper = EarlyStopping(patience=10, verbose=1)
checkpointer = ModelCheckpoint('model-2-dsbowl2018.h5', verbose=1, save_best_only=True)
results = u_net.fit(preproc_imgs,train_masks, validation_split=0.1, batch_size=8, epochs=50, 
                    callbacks=[checkpointer])
# Out:
# Training...
# Train on 603 samples, validate on 67 samples
# Epoch 1/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.3979 - mean_iou: 8.1573e-04
# Epoch 00001: val_loss improved from inf to 0.25061, saving model to model-2-dsbowl2018.h5
# 603/603 [==============================] - 13s 22ms/step - loss: 0.3980 - mean_iou: 8.2259e-04 - val_loss: 0.2506 - val_mean_iou: 0.0021
# Epoch 2/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.2148 - mean_iou: 0.0208
# Epoch 00002: val_loss improved from 0.25061 to 0.19505, saving model to model-2-dsbowl2018.h5
# 603/603 [==============================] - 13s 21ms/step - loss: 0.2150 - mean_iou: 0.0210 - val_loss: 0.1950 - val_mean_iou: 0.0660
# Epoch 3/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1741 - mean_iou: 0.1006
# Epoch 00003: val_loss improved from 0.19505 to 0.14421, saving model to model-2-dsbowl2018.h5
# 603/603 [==============================] - 13s 21ms/step - loss: 0.1737 - mean_iou: 0.1007 - val_loss: 0.1442 - val_mean_iou: 0.1317
# Epoch 4/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1690 - mean_iou: 0.1521
# Epoch 00004: val_loss improved from 0.14421 to 0.12896, saving model to model-2-dsbowl2018.h5
# 603/603 [==============================] - 13s 21ms/step - loss: 0.1691 - mean_iou: 0.1522 - val_loss: 0.1290 - val_mean_iou: 0.1683
# Epoch 5/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1563 - mean_iou: 0.1825
# Epoch 00005: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.1562 - mean_iou: 0.1826 - val_loss: 0.1468 - val_mean_iou: 0.1949
# Epoch 6/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1551 - mean_iou: 0.2030
# Epoch 00006: val_loss improved from 0.12896 to 0.12587, saving model to model-2-dsbowl2018.h5
# 603/603 [==============================] - 13s 22ms/step - loss: 0.1552 - mean_iou: 0.2030 - val_loss: 0.1259 - val_mean_iou: 0.2111
# Epoch 7/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1435 - mean_iou: 0.2191
# Epoch 00007: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.1433 - mean_iou: 0.2192 - val_loss: 0.1285 - val_mean_iou: 0.2259
# Epoch 8/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1558 - mean_iou: 0.2308
# Epoch 00008: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.1556 - mean_iou: 0.2308 - val_loss: 0.1288 - val_mean_iou: 0.2351
# Epoch 9/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1511 - mean_iou: 0.2386
# Epoch 00009: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.1507 - mean_iou: 0.2387 - val_loss: 0.1462 - val_mean_iou: 0.2419
# Epoch 10/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1501 - mean_iou: 0.2455
# Epoch 00010: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.1506 - mean_iou: 0.2455 - val_loss: 0.1465 - val_mean_iou: 0.2480
# Epoch 11/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1429 - mean_iou: 0.2504
# Epoch 00011: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.1431 - mean_iou: 0.2504 - val_loss: 0.1280 - val_mean_iou: 0.2530
# Epoch 12/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1627 - mean_iou: 0.2547
# Epoch 00012: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.1627 - mean_iou: 0.2548 - val_loss: 0.1320 - val_mean_iou: 0.2559
# Epoch 13/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1436 - mean_iou: 0.2580
# Epoch 00013: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.1445 - mean_iou: 0.2580 - val_loss: 0.1302 - val_mean_iou: 0.2597
# Epoch 14/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1371 - mean_iou: 0.2611
# Epoch 00014: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.1371 - mean_iou: 0.2611 - val_loss: 0.1305 - val_mean_iou: 0.2628
# Epoch 15/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1404 - mean_iou: 0.2645
# Epoch 00015: val_loss improved from 0.12587 to 0.12309, saving model to model-2-dsbowl2018.h5
# 603/603 [==============================] - 13s 22ms/step - loss: 0.1403 - mean_iou: 0.2645 - val_loss: 0.1231 - val_mean_iou: 0.2658
# Epoch 16/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1565 - mean_iou: 0.2666
# Epoch 00016: val_loss improved from 0.12309 to 0.12100, saving model to model-2-dsbowl2018.h5
# 603/603 [==============================] - 13s 22ms/step - loss: 0.1561 - mean_iou: 0.2666 - val_loss: 0.1210 - val_mean_iou: 0.2672
# Epoch 17/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1403 - mean_iou: 0.2688
# Epoch 00017: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.1401 - mean_iou: 0.2688 - val_loss: 0.1287 - val_mean_iou: 0.2698
# Epoch 18/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1449 - mean_iou: 0.2708
# Epoch 00018: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.1448 - mean_iou: 0.2708 - val_loss: 0.1530 - val_mean_iou: 0.2715
# Epoch 19/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1461 - mean_iou: 0.2720
# Epoch 00019: val_loss improved from 0.12100 to 0.11780, saving model to model-2-dsbowl2018.h5
# 603/603 [==============================] - 13s 22ms/step - loss: 0.1461 - mean_iou: 0.2720 - val_loss: 0.1178 - val_mean_iou: 0.2730
# Epoch 20/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1388 - mean_iou: 0.2742
# Epoch 00020: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.1387 - mean_iou: 0.2742 - val_loss: 0.1262 - val_mean_iou: 0.2748
# Epoch 21/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1423 - mean_iou: 0.2756
# Epoch 00021: val_loss improved from 0.11780 to 0.11580, saving model to model-2-dsbowl2018.h5
# 603/603 [==============================] - 13s 22ms/step - loss: 0.1420 - mean_iou: 0.2756 - val_loss: 0.1158 - val_mean_iou: 0.2763
# Epoch 22/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1390 - mean_iou: 0.2773
# Epoch 00022: val_loss did not improve
# 603/603 [==============================] - 13s 22ms/step - loss: 0.1389 - mean_iou: 0.2773 - val_loss: 0.1168 - val_mean_iou: 0.2779
# Epoch 23/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1255 - mean_iou: 0.2789
# Epoch 00023: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.1254 - mean_iou: 0.2789 - val_loss: 0.1166 - val_mean_iou: 0.2801
# Epoch 24/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1136 - mean_iou: 0.2819
# Epoch 00024: val_loss improved from 0.11580 to 0.10509, saving model to model-2-dsbowl2018.h5
# 603/603 [==============================] - 13s 22ms/step - loss: 0.1136 - mean_iou: 0.2819 - val_loss: 0.1051 - val_mean_iou: 0.2834
# Epoch 25/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1141 - mean_iou: 0.2848
# Epoch 00025: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.1141 - mean_iou: 0.2848 - val_loss: 0.1091 - val_mean_iou: 0.2861
# Epoch 26/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1140 - mean_iou: 0.2874
# Epoch 00026: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.1139 - mean_iou: 0.2874 - val_loss: 0.1085 - val_mean_iou: 0.2888
# Epoch 27/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1033 - mean_iou: 0.2900
# Epoch 00027: val_loss improved from 0.10509 to 0.10213, saving model to model-2-dsbowl2018.h5
# 603/603 [==============================] - 13s 22ms/step - loss: 0.1032 - mean_iou: 0.2900 - val_loss: 0.1021 - val_mean_iou: 0.2915
# Epoch 28/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.1025 - mean_iou: 0.2929
# Epoch 00028: val_loss improved from 0.10213 to 0.09585, saving model to model-2-dsbowl2018.h5
# 603/603 [==============================] - 13s 22ms/step - loss: 0.1022 - mean_iou: 0.2929 - val_loss: 0.0959 - val_mean_iou: 0.2943
# Epoch 29/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.0949 - mean_iou: 0.2958
# Epoch 00029: val_loss improved from 0.09585 to 0.09341, saving model to model-2-dsbowl2018.h5
# 603/603 [==============================] - 13s 22ms/step - loss: 0.0948 - mean_iou: 0.2958 - val_loss: 0.0934 - val_mean_iou: 0.2970
# Epoch 30/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.0970 - mean_iou: 0.2983
# Epoch 00030: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.0969 - mean_iou: 0.2983 - val_loss: 0.0950 - val_mean_iou: 0.2996
# Epoch 31/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.0953 - mean_iou: 0.3008
# Epoch 00031: val_loss improved from 0.09341 to 0.09201, saving model to model-2-dsbowl2018.h5
# 603/603 [==============================] - 13s 22ms/step - loss: 0.0957 - mean_iou: 0.3008 - val_loss: 0.0920 - val_mean_iou: 0.3020
# Epoch 32/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.0933 - mean_iou: 0.3031
# Epoch 00032: val_loss improved from 0.09201 to 0.09133, saving model to model-2-dsbowl2018.h5
# 603/603 [==============================] - 13s 22ms/step - loss: 0.0934 - mean_iou: 0.3031 - val_loss: 0.0913 - val_mean_iou: 0.3043
# Epoch 33/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.0939 - mean_iou: 0.3054
# Epoch 00033: val_loss improved from 0.09133 to 0.08671, saving model to model-2-dsbowl2018.h5
# 603/603 [==============================] - 13s 22ms/step - loss: 0.0943 - mean_iou: 0.3054 - val_loss: 0.0867 - val_mean_iou: 0.3064
# Epoch 34/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.0920 - mean_iou: 0.3075
# Epoch 00034: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.0921 - mean_iou: 0.3075 - val_loss: 0.0900 - val_mean_iou: 0.3085
# Epoch 35/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.0928 - mean_iou: 0.3095
# Epoch 00035: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.0931 - mean_iou: 0.3095 - val_loss: 0.0892 - val_mean_iou: 0.3104
# Epoch 36/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.0905 - mean_iou: 0.3114
# Epoch 00036: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.0905 - mean_iou: 0.3114 - val_loss: 0.0867 - val_mean_iou: 0.3123
# Epoch 37/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.0956 - mean_iou: 0.3132
# Epoch 00037: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.0952 - mean_iou: 0.3132 - val_loss: 0.0899 - val_mean_iou: 0.3140
# Epoch 38/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.0925 - mean_iou: 0.3149
# Epoch 00038: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.0924 - mean_iou: 0.3149 - val_loss: 0.0989 - val_mean_iou: 0.3156
# Epoch 39/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.0908 - mean_iou: 0.3164
# Epoch 00039: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.0911 - mean_iou: 0.3164 - val_loss: 0.1006 - val_mean_iou: 0.3171
# Epoch 40/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.0883 - mean_iou: 0.3180
# Epoch 00040: val_loss improved from 0.08671 to 0.08247, saving model to model-2-dsbowl2018.h5
# 603/603 [==============================] - 13s 22ms/step - loss: 0.0886 - mean_iou: 0.3180 - val_loss: 0.0825 - val_mean_iou: 0.3187
# Epoch 41/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.0861 - mean_iou: 0.3195
# Epoch 00041: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.0867 - mean_iou: 0.3195 - val_loss: 0.0898 - val_mean_iou: 0.3202
# Epoch 42/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.0861 - mean_iou: 0.3210
# Epoch 00042: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.0860 - mean_iou: 0.3210 - val_loss: 0.0839 - val_mean_iou: 0.3218
# Epoch 43/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.0897 - mean_iou: 0.3225
# Epoch 00043: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.0896 - mean_iou: 0.3225 - val_loss: 0.0937 - val_mean_iou: 0.3231
# Epoch 44/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.0843 - mean_iou: 0.3238
# Epoch 00044: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.0843 - mean_iou: 0.3238 - val_loss: 0.0875 - val_mean_iou: 0.3245
# Epoch 45/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.0838 - mean_iou: 0.3252
# Epoch 00045: val_loss improved from 0.08247 to 0.08170, saving model to model-2-dsbowl2018.h5
# 603/603 [==============================] - 13s 22ms/step - loss: 0.0842 - mean_iou: 0.3252 - val_loss: 0.0817 - val_mean_iou: 0.3259
# Epoch 46/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.0899 - mean_iou: 0.3266
# Epoch 00046: val_loss improved from 0.08170 to 0.08169, saving model to model-2-dsbowl2018.h5
# 603/603 [==============================] - 13s 22ms/step - loss: 0.0901 - mean_iou: 0.3266 - val_loss: 0.0817 - val_mean_iou: 0.3272
# Epoch 47/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.0848 - mean_iou: 0.3278
# Epoch 00047: val_loss improved from 0.08169 to 0.07921, saving model to model-2-dsbowl2018.h5
# 603/603 [==============================] - 13s 22ms/step - loss: 0.0850 - mean_iou: 0.3278 - val_loss: 0.0792 - val_mean_iou: 0.3285
# Epoch 48/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.0884 - mean_iou: 0.3291
# Epoch 00048: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.0887 - mean_iou: 0.3291 - val_loss: 0.0810 - val_mean_iou: 0.3296
# Epoch 49/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.0851 - mean_iou: 0.3302
# Epoch 00049: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.0851 - mean_iou: 0.3302 - val_loss: 0.0827 - val_mean_iou: 0.3308
# Epoch 50/50
# 600/603 [============================>.] - ETA: 0s - loss: 0.0835 - mean_iou: 0.3314
# Epoch 00050: val_loss did not improve
# 603/603 [==============================] - 13s 21ms/step - loss: 0.0831 - mean_iou: 0.3314 - val_loss: 0.0866 - val_mean_iou: 0.3320

# %% [markdown]
# ## 7) Prediction (testing)
#
# Performance did not differ much between the two trained models above, so we'll use the model trained on data without preprocessing.
#
# #### Let's use the trainned model to predict on the test images.
#
# I'll also predict on the training and validation sets just for sanity check later.

# %%
#del model
#del u_net

# %%
print("Predicting")
## Predict on test data

TRAIN_DATA = train_imgs #preproc_imgs
TEST_DATA = test_imgs #train_masks #preproc_test_imgs

# Predict on train, val and test
#model = load_model('unet_simple_model_150epochs.h5', custom_objects={'dice_coef': dice_coef})
model.load_weights('unet_simple_model_150epochs_weights.h5')
preds_train = model.predict(TRAIN_DATA[:int(TRAIN_DATA.shape[0]*0.9)], verbose=1)
preds_val = model.predict(TRAIN_DATA[int(TRAIN_DATA.shape[0]*0.9):], verbose=1)
preds_test = model.predict(TEST_DATA, verbose=1)
preds_test = model.predict(TEST_DATA, verbose=1)


# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (test_img_sizes[i][0], test_img_sizes[i][1]), 
                                       mode='constant', preserve_range=True))
# Out:
# Predicting
# 603/603 [==============================] - 133s 221ms/step
# 67/67 [==============================] - 13s 195ms/step
# 65/65 [==============================] - 13s 196ms/step
# 65/65 [==============================] - 13s 200ms/step

# %%
#model.save_weights('unet_simple_model_150epochs_weights.h5')

# %% [markdown]
# ## 8) Visualize Results
#
# Now that the model has successfully ran, let's take a look at the results.
#
# #### Check that it does ok on the trainning data

# %%
# Perform a sanity check on some random training samples
ix = 139 # random.randint(0, len(preds_train_t)) # 138 nice large bw cells, 139 purple and white messy
print('Trainning example No.',ix)

hdf5_mask=np.squeeze(np.transpose(hdf5_train_masks,(0,2,3,1))[ix])

fig = plt.figure(figsize=(16, 16))
plt.subplot(141).set_title('Original Image')
plt.imshow(train_imgs[ix])
plt.subplot(142).set_title('Mask (Target)')
plt.imshow(np.squeeze(train_masks[ix]), cmap='gray')
plt.subplot(143).set_title('Predicted Mask')
plt.imshow(np.squeeze(preds_train[ix]),cmap='gray')
plt.subplot(144).set_title('Predicted Mask Threshold')
plt.imshow(np.squeeze(preds_train_t[ix]),cmap='gray')
plt.show()
# Out:
# ('Trainning example No.', 139)

# %% [markdown]
# ### Check that it does ok on the validation data

# %%
# Perform a sanity check on some random validation samples
ix = random.randint(0, len(preds_val_t))
print("Random sample from validation set no.",ix)
val_img=train_imgs[int(train_imgs.shape[0]*0.9):][ix]
val_mask=np.squeeze(train_masks[int(train_masks.shape[0]*0.9):][ix])

fig3 = plt.figure(figsize=(16, 16))
plt.subplot(141).set_title('Original Image')
plt.imshow(val_img)
plt.subplot(142).set_title('Mask (Target)')
plt.imshow(np.squeeze(val_mask), cmap='gray')
plt.subplot(143).set_title('Predicted Mask')
plt.imshow(np.squeeze(preds_val[ix]), cmap='gray')
plt.subplot(144).set_title('Predicted Mask Threshold')
plt.imshow(np.squeeze(preds_val_t[ix]), cmap='gray')
plt.show()
# Out:
# ('Random sample from validation set no.', 64)

# %% [markdown]
# ### Finally, let's check how it did on the test dataset

# %%
# Check if test data looks all right
ix = 12# random.randint(0, test_imgs.shape[0]) # 50/57 easy, 42 medium, 7/37/24 hard,  9 bw small, 59 good example bw, 12 many cells in color, 54 many cells bw, 62 messy, 5 monster
print(ix)

fig4 = plt.figure(figsize=(16, 16))
plt.subplot(141).set_title('Original Image')
plt.imshow(test_imgs[ix])
plt.subplot(142).set_title('Preprocessed')
plt.imshow(preproc_test_imgs[ix])
plt.subplot(143).set_title('Predicted Mask')
plt.imshow(np.squeeze(preds_test[ix]), cmap='gray')
plt.subplot(144).set_title('Predicted Mask Thresholded')
plt.imshow(np.squeeze(preds_test_t[ix]), cmap='gray')
plt.show()
# Out:
# 12

# %% [markdown]
# This looks very reasonable.

# %% [markdown]
# ## 9) Cell counting
#
# Implement a function to count the number of cells within an image.
# Here I used a combination of functions from the opencv package.

# %%
# Count cells using predicted mask

original_img=test_imgs[ix] #original image
img0 = original_img.copy()
#img0 = np.asarray(original_img)
plt.imshow(img0)
plt.show()

def count_cells(pred_mask, t=65):
    
    img_mask=np.squeeze(pred_mask)
    plt.imsave('test.png', img_mask)

    image = Image.open('test.png').convert("L")
    img = np.asarray(image)
    img = img.copy()
    blur = cv2.GaussianBlur(img, (5, 5), 0)
    (t, binary) = cv2.threshold(blur, t, 255, cv2.THRESH_BINARY)

    # find contours
    (_, contours, _) = cv2.findContours(binary, cv2.RETR_EXTERNAL, 
    cv2.CHAIN_APPROX_SIMPLE)

    # create all-black mask image
    mask = np.zeros(img.shape, dtype="uint8")

    # draw white rectangles for each object's bounding box
    for c in contours:
        (x, y, w, h) = cv2.boundingRect(c)
        cv2.rectangle(mask, (x, y), (x + w, y + h), (255, 255, 255), -1)

    # draw contours over original image
    cv2.drawContours(img, contours, -1, (255, 100, 100), 1)

    plt.imshow(img)
    plt.show()

    # print table of contours and sizes
    print("Found %d cells." % len(contours))
    for (i, c) in enumerate(contours):
        print("\tSize of cell %d: %d" % (i, len(c)))
    return

count_cells(preds_test[ix], t=65)
# Out:
# Found 73 cells.
# 	Size of cell 0: 21
# 	Size of cell 1: 6
# 	Size of cell 2: 12
# 	Size of cell 3: 11
# 	Size of cell 4: 13
# 	Size of cell 5: 50
# 	Size of cell 6: 18
# 	Size of cell 7: 5
# 	Size of cell 8: 29
# 	Size of cell 9: 15
# 	Size of cell 10: 38
# 	Size of cell 11: 15
# 	Size of cell 12: 8
# 	Size of cell 13: 15
# 	Size of cell 14: 40
# 	Size of cell 15: 30
# 	Size of cell 16: 31
# 	Size of cell 17: 14
# 	Size of cell 18: 20
# 	Size of cell 19: 6
# 	Size of cell 20: 7
# 	Size of cell 21: 17
# 	Size of cell 22: 13
# 	Size of cell 23: 17
# 	Size of cell 24: 54
# 	Size of cell 25: 15
# 	Size of cell 26: 8
# 	Size of cell 27: 7
# 	Size of cell 28: 24
# 	Size of cell 29: 17
# 	Size of cell 30: 13
# 	Size of cell 31: 8
# 	Size of cell 32: 20
# 	Size of cell 33: 12
# 	Size of cell 34: 14
# 	Size of cell 35: 34
# 	Size of cell 36: 15
# 	Size of cell 37: 17
# 	Size of cell 38: 16
# 	Size of cell 39: 31
# 	Size of cell 40: 38
# 	Size of cell 41: 32
# 	Size of cell 42: 17
# 	Size of cell 43: 18
# 	Size of cell 44: 9
# 	Size of cell 45: 12
# 	Size of cell 46: 15
# 	Size of cell 47: 11
# 	Size of cell 48: 17
# 	Size of cell 49: 12
# 	Size of cell 50: 11
# 	Size of cell 51: 18
# 	Size of cell 52: 17
# 	Size of cell 53: 9
# 	Size of cell 54: 2
# 	Size of cell 55: 3
# 	Size of cell 56: 18
# 	Size of cell 57: 22
# 	Size of cell 58: 8
# 	Size of cell 59: 11
# 	Size of cell 60: 21
# 	Size of cell 61: 13
# 	Size of cell 62: 32
# 	Size of cell 63: 18
# 	Size of cell 64: 11
# 	Size of cell 65: 12
# 	Size of cell 66: 16
# 	Size of cell 67: 13
# 	Size of cell 68: 14
# 	Size of cell 69: 8
# 	Size of cell 70: 33
# 	Size of cell 71: 12
# 	Size of cell 72: 11

# %% [markdown]
# ## Final thoughts
#
# The final result from this pipeline is a segmented image with cells counted. It works well as a first prototype and proof of concept but there is much room for improvement; for example, some of the cells overlap and get clustered together as one single cell, which also leads to under counting. Future post-processing using water shed techniques should help with this. Additionally, I'd like to try other network architectures including R-CNN.
